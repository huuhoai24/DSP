# %%
import pandas as pd

val = pd.read_csv("val_1vv.csv")
test = pd.read_csv("text1111.csv")

# %%
# test.info()
val.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      156 non-null    str
#  1   label     156 non-null    str
#  2   severity  156 non-null    str
# dtypes: str(3)
# memory usage: 22.2 KB

# %%
val.head
# Out:
# <bound method NDFrame.head of                                                   text             label  \
# 0    Tôi hiện đang có các triệu chứng như sốt cao, ...       respiratory
# 1    Tôi đang bị sốt cao, đổ mồ hôi và khó thở nặng...       respiratory
# 2    Tôi cảm thấy khó thở, tức ngực dữ dội và sốt c...       respiratory
# 3    Tôi ho ra máu tươi, sút cân nhanh, mệt lả. Tôi...       respiratory
# 4    Tôi khó thở khi nằm, phải kê cao gối, ho về đê...       respiratory
# ..                                                 ...               ...
# 151  Tôi đầy bụng, khó tiêu, ợ nóng sau khi ăn no. ...  gastroenterology
# 152  Tôi tiêu chảy kéo dài, phân có nhầy, mệt mỏi. ...  gastroenterology
# 153  Tôi đau bụng quặn từng cơn, nôn nhiều, chán ăn...  gastroenterology
# 154  Tôi vàng da, ngứa da toàn thân, mệt mỏi. Tôi c...  gastroenterology
# 155  Tôi hay bị nổi mẩn đỏ khắp người kèm theo sốt ...       dermatology
#
#      severity
# 0    moderate
# 1      severe
# 2      severe
# ...
